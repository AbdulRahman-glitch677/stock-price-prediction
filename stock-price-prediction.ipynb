# %% [markdown]
# # FIND THE STCCK FILES

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames[:20]:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/ufi.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/vfl.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/sohu.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/rdcm.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/virt.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/hylb.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/skt.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/asix.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/mac.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/gut.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/ngs.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/vpg.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/ibtx.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/coda.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/evlmc.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/crd-b.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/matx.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/htf-cl.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/sid.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/pol.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/djci.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/sqqq.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/ipac.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/vb.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/cper.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/rjz.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/pdn.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/ixn.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/acwi.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/pscc.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/pick.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/qqqc.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/rdiv.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/kba.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/bscn.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/mort.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/wmcr.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/ewj.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/fko.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/ETFs/sdy.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/ufi.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/vfl.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/sohu.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/rdcm.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/virt.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/hylb.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/skt.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/asix.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/mac.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/gut.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/ngs.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/vpg.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/ibtx.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/coda.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/evlmc.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/crd-b.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/matx.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/htf-cl.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/sid.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/Stocks/pol.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/djci.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/sqqq.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ipac.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/vb.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/cper.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/rjz.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pdn.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ixn.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/acwi.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pscc.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/pick.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/qqqc.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/rdiv.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/kba.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/bscn.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/mort.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/wmcr.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/ewj.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/fko.us.txt
# /kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Data/ETFs/sdy.us.txt

# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
# Out:
# 2026-05-31 13:06:19.076579: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780232779.595834      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780232779.707284      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780232780.826394      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780232780.826441      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780232780.826444      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780232780.826447      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# # LOAD THE DATA

# %%
df = pd.read_csv(
    "/kaggle/input/datasets/borismarjanovic/price-volume-data-for-all-us-stocks-etfs/Stocks/sohu.us.txt"
)

print(df.shape)
df.head()
# Out:
# (3201, 7)
#          Date   Open   High    Low  Close   Volume  OpenInt
# 0  2005-02-25  16.46  16.89  16.46  16.83   874643        0
# 1  2005-02-28  16.75  18.30  16.75  17.92  3676074        0
# 2  2005-03-01  17.87  19.23  17.86  18.80  3574093        0
# 3  2005-03-02  18.68  18.89  18.10  18.28  1709915        0
# 4  2005-03-03  18.41  19.31  18.27  18.94  2947206        0

# %% [markdown]
# # CHECK COLUMNS

# %%
print(df.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')
# (3201, 7)

# %% [markdown]
# # CONVERT DATE

# %%
df['Date'] = pd.to_datetime(df['Date'])

df = df.sort_values('Date')

df.head()
# Out:
#         Date   Open   High    Low  Close   Volume  OpenInt
# 0 2005-02-25  16.46  16.89  16.46  16.83   874643        0
# 1 2005-02-28  16.75  18.30  16.75  17.92  3676074        0
# 2 2005-03-01  17.87  19.23  17.86  18.80  3574093        0
# 3 2005-03-02  18.68  18.89  18.10  18.28  1709915        0
# 4 2005-03-03  18.41  19.31  18.27  18.94  2947206        0

# %% [markdown]
# # MOVING AVERAGES

# %%
df['MA20'] = df['Close'].rolling(20).mean()

df['MA50'] = df['Close'].rolling(50).mean()

# %% [markdown]
# # RSI

# %%
delta = df['Close'].diff()

gain = delta.where(delta > 0, 0)
loss = -delta.where(delta < 0, 0)

avg_gain = gain.rolling(14).mean()
avg_loss = loss.rolling(14).mean()

rs = avg_gain / avg_loss

df['RSI'] = 100 - (100 / (1 + rs))

# %% [markdown]
# # REMOVE MISSING VALUES

# %%
df = df.dropna()

print(df.shape)
# Out:
# (3152, 10)

# %% [markdown]
# # USE CLOSE PRICE

# %%
data = df[['Close']].values

# %% [markdown]
# # NORMALLIZE

# %%
scaler = MinMaxScaler()

data_scaled = scaler.fit_transform(data)

# %% [markdown]
# # CREATE SEQUENCES

# %%
X = []
y = []

for i in range(60, len(data_scaled)):
    X.append(data_scaled[i-60:i, 0])
    y.append(data_scaled[i, 0])

X = np.array(X)
y = np.array(y)

X = np.reshape(
    X,
    (X.shape[0], X.shape[1], 1)
)

print(X.shape)
print(y.shape)
# Out:
# (3092, 60, 1)
# (3092,)

# %% [markdown]
# # TRAIN-TEST-SPLIT

# %%
split = int(len(X) * 0.8)

X_train = X[:split]
X_test = X[split:]

y_train = y[:split]
y_test = y[split:]

# %% [markdown]
# # BUILD LSTM

# %%
model = Sequential()

model.add(
    LSTM(
        50,
        return_sequences=False,
        input_shape=(X_train.shape[1], 1)
    )
)

model.add(Dense(1))

model.compile(
    optimizer='adam',
    loss='mse'
)

model.summary()
# Out:
# I0000 00:00:1780233137.222108      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780233137.227937      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 50)             │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,451 (40.82 KB)
#  Trainable params: 10,451 (40.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # TRAIN MODEL

# %%
history = model.fit(
    X_train,
    y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/20
# I0000 00:00:1780233180.853738     177 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - loss: 0.0236 - val_loss: 0.0013
# Epoch 2/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 3/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 4/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0017 - val_loss: 8.6401e-04
# Epoch 5/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0015 - val_loss: 8.4090e-04
# Epoch 6/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0014 - val_loss: 7.3216e-04
# Epoch 7/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0013 - val_loss: 7.4393e-04
# Epoch 8/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0012 - val_loss: 7.4703e-04
# Epoch 9/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0011 - val_loss: 6.0703e-04
# Epoch 10/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0011 - val_loss: 5.9041e-04
# Epoch 11/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0010 - val_loss: 5.9867e-04
# Epoch 12/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0011 - val_loss: 7.1409e-04
# Epoch 13/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.7685e-04 - val_loss: 5.1275e-04
# Epoch 14/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.3304e-04 - val_loss: 5.6078e-04
# Epoch 15/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.8828e-04 - val_loss: 5.4996e-04
# Epoch 16/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.5116e-04 - val_loss: 4.6141e-04
# Epoch 17/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.2223e-04 - val_loss: 4.1035e-04
# Epoch 18/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.2383e-04 - val_loss: 4.5823e-04
# Epoch 19/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.1048e-04 - val_loss: 3.8443e-04
# Epoch 20/20
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.5102e-04 - val_loss: 4.4053e-04

# %% [markdown]
# # PREDICTION

# %%
predictions = model.predict(X_test)

predictions = scaler.inverse_transform(predictions.reshape(-1,1))

actual = scaler.inverse_transform(
    y_test.reshape(-1,1)
)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# # RMSE

# %%
rmse = np.sqrt(
    mean_squared_error(
        actual,
        predictions
    )
)

print("RMSE:", rmse)
# Out:
# RMSE: 1.912914712953255

# %% [markdown]
# # ACTUAL VS PREDICTED

# %%
plt.figure(figsize=(12,6))

plt.plot(actual, label='Actual')

plt.plot(predictions, label='Predicted')

plt.title('Stock Price Prediction')

plt.xlabel('Time')

plt.ylabel('Price')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.plot(df['Date'], df['Close'])

plt.title("Historical Stock Price")

plt.xlabel("Date")

plt.ylabel("Close Price")

plt.show()
